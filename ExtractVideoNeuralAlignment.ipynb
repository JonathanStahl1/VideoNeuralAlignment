# %%
# Import relevant modules

import numpy as np
import pandas as pd
import datajoint as dj
import cv2
import os
import re

# %%
# Connect to Datajoint
 
dj.config['database.host'] = "arseny-lab.cmte3q4ziyvy.il-central-1.rds.amazonaws.com"
dj.config['database.user'] = "JonathanStahl"
dj.config['database.password'] = "HeadDirection621."
conn = dj.conn()
# Out:
# [2025-03-24 21:52:18,032][INFO]: Connecting JonathanStahl@arseny-lab.cmte3q4ziyvy.il-central-1.rds.amazonaws.com:3306
# [2025-03-24 21:52:18,880][INFO]: Connected JonathanStahl@arseny-lab.cmte3q4ziyvy.il-central-1.rds.amazonaws.com:3306

# %%
# Get video neural alignment data
# video_neural_alignment_table = video_neural_schema.VideoNeuralAlignment
# q = pd.DataFrame(video_neural_alignment_table.fetch(limit = 10))
# q

# %%
def get_all_trial_video_frames(trial_video_file_path):
    cap = cv2.VideoCapture(trial_video_file_path)
    frames_list= []

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frames_list.append(frame)

    return frames_list

# %%
def aligned_trial_video_frames(trial_video_frames_indexes, frames_list):
    aligned_trial_video_frames = []
    for index_range in trial_video_frames_indexes:
        if index_range == []:
            continue
        if index_range[1] + 1 == len(frames_list):
            aligned_trial_video_frames.append(frames_list[index_range[0]:])
            continue
        aligned_trial_video_frames.append(frames_list[index_range[0]:index_range[1] + 1])

    return aligned_trial_video_frames

# %%
def get_trial_video_frames_groups(row, all_videos_path, subject_id, session_string, camera_num):
    trial_num = row["tracking_datafile_num"]
    video_file_name = f"video_cam_{camera_num}_v{trial_num:03d}.avi"
    trial_video_file_path = os.path.join(all_videos_path, subject_id, session_string, video_file_name)
    trial_frame_list = get_all_trial_video_frames(trial_video_file_path)
    trial_video_frames_indexes = row["trial_video_frames_indexes_groups"]
    return aligned_trial_video_frames(trial_video_frames_indexes , trial_frame_list)

# %%
def get_trials_data_table_for_mouse_session(subject_id, session, camera_num = 3):
    # Get all relevant schemas
    tracking = dj.VirtualModule('TRACKING', 'arseny_learning_tracking')
    video_neural_schema = dj.VirtualModule('VIDEONEURAL', f"{dj.config['database.user']}_VIDEONEURAL")
    key = {'subject_id': subject_id, 'session': session}
    tracking_trials = tracking.TrackingTrial
    video_neural_alignment_table = video_neural_schema.VideoNeuralAlignment
    return pd.DataFrame((tracking_trials * video_neural_alignment_table & key & {'tracking_device_id': camera_num}).fetch())

# %%
def get_dff_table_for_mouse_session(subject_id, session):
    img = dj.VirtualModule('IMG', 'arseny_learning_imaging')
    key = {"subject_id" : subject_id, "session" : session, "session_epoch_type" : "behav_only"}
    ROIdeltaF = pd.DataFrame(((img.ROIdeltaF & key)).fetch())
    dff_trace_matrix = pd.DataFrame([x[0] for x in ROIdeltaF["dff_trace"]])
    return pd.concat([ROIdeltaF.drop(["dff_trace", "session_epoch_type", "subject_id", "session"], axis='columns'), dff_trace_matrix], axis=1)

# %%
def get_trial_neural_frames(dff_data, trial_neural_frames_indexes, video_groups_length = null, remove_neural_frames_with_no_video = True):
    if remove_neural_frames_with_no_video:
        if video_groups_length == null:
            raise "Can't remove neural frames with no video without video_group_length"
        trial_neural_frames = dff_data[trial_neural_frames_indexes[:video_groups_length]]
    else:
        trial_neural_frames = dff_data[trial_neural_frames_indexes]
    
    return trial_neural_frames

# %%
subject_id = "463189"
session = 1
trials_data = get_trials_data_table_for_mouse_session(subject_id, session)
dff_data = get_dff_table_for_mouse_session(subject_id, session)
# Out:
# [2025-03-24 21:52:31,399][WARNING]: MySQL server has gone away. Reconnecting to the server.

# %%
def get_session_aligned_frames_per_trial(subject_id, session, remove_neural_frames_with_no_video = True):
    session_string = f"session{session}"
    camera_num = 0
    all_videos_path = "D:\\admin\\SharedFolder\\Arseny_behavior_video"
    
    trials_data = get_trials_data_table_for_mouse_session(subject_id, session)
    dff_data = get_dff_table_for_mouse_session(subject_id, session)

    aligned_data = pd.DataFrame(columns=["trial", "trial_neural_frames", "trial_video_frames_groups"])
    for index, row in trials_data.iterrows():
        trial_video_frames_groups = get_trial_video_frames_groups(row, all_videos_path, subject_id, session_string, camera_num)
        trial_neural_frames = get_trial_neural_frames(dff_data, row["trial_neural_frames_indexes"], remove_neural_frames_with_no_video)
        new_row = {"trial": row["trial"], 'trial_neural_frames': trial_neural_frames, 'trial_video_frames_groups': trial_video_frames_groups}

        # Insert the row at the end using loc
        aligned_data.loc[len(aligned_data)] = new_row

        
    return aligned_data



x = get_session_aligned_frames()
print("hi")
# Out:
# 00{"name":"NameError","message":"name 'trial_neural_frames' is not defined","stack":["Traceback \u001b(most recent call last)\u001b:\n","\u001b  File \u001b<string>:174\u001b in \u001b__DW_DEBUG_WRAPPER__\u001b\n","\u001b  File \u001b<string>:163\u001b in \u001b__DW_GET_EXPRESSION_VARIABLE__\u001b\n","\u001bNameError\u001b\u001b:\u001b name 'trial_neural_frames' is not defined\n"]}

# %%
def get_session_aligned_frames(subject_id, session, remove_neural_frames_with_no_video = True):
    df = get_session_aligned_frames_per_trial(subject_id, session, remove_neural_frames_with_no_video)


    return dff_data, video_df

# %%
# all_videos_path = "D:\\admin\\SharedFolder\\Arseny_behavior_video"
# video_folder_path = os.path.join(all_videos_path, subject_id, f"session{session}")
# video_files = sorted(os.listdir(video_folder_path))
# pattern = re.compile(f"video_cam_{camera_num}_v(\d+)")
# filtered_video_files = [f for f in video_files if pattern.match(f)]


# trials = tracking.TrackingTrial & key & {'tracking_device_id': 3}

# trials_table = trials.fetch()


# for video_file in filtered_video_files:
#     video_file_path = os.path.join(video_folder_path, video_file)
#     cap = cv2.VideoCapture(video_file_path)
#     frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
#     print(frame_count)
# Out:
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
# 15271
#